# %%
import pandas as pd
# %matplotlib inline

# %%
elespectador_df = pd.read_csv('clean_elespectador_2021_06_30_articles.csv')
vanguardia_df = pd.read_csv('clean_vanguardia_2021_06_30_articles.csv')

# %%
elespectador_df.describe()
# Out:
#        n_tokens_title  n_tokens_summary
# count       11.000000         11.000000
# mean         6.272727         17.454545
# std          1.618080          3.984059
# min          4.000000          9.000000
# 25%          5.000000         16.000000
# 50%          7.000000         17.000000
# 75%          7.500000         19.000000
# max          8.000000         25.000000

# %%
vanguardia_df.describe()
# Out:
#        n_tokens_title  n_tokens_summary
# count       20.000000         20.000000
# mean         6.350000         17.150000
# std          1.496487          4.120232
# min          4.000000          9.000000
# 25%          5.000000         15.000000
# 50%          6.500000         17.000000
# 75%          7.000000         20.000000
# max          9.000000         27.000000

# %%
elespectador_df['n_tokens_title'].plot(style='.k')
vanguardia_df['n_tokens_title'].plot(style='.r')
# Out:
# <AxesSubplot:>

# %%
elespectador_df['n_tokens_summary'].plot(style='.k')
vanguardia_df['n_tokens_summary'].plot(style='.r')
# Out:
# <AxesSubplot:>

# %%
all_df = pd.concat([elespectador_df, vanguardia_df])
grouped = all_df.groupby('newspaper')

# %%
grouped.hist(bins=4)
# Out:
# newspaper
# elespectador    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# vanguardia      [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_summary'].agg(['min','mean','max'])
# Out:
#               min       mean  max
# newspaper
# elespectador    9  17.454545   25
# vanguardia      9  17.150000   27
